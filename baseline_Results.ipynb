# %%
baseline_results = {
    "model": "Logistic Regression",
    "accuracy": 0.8689,
    "f1_score": 0.8667,
    "roc_auc": 0.9535
}

print(baseline_results)
# Out:
# {'model': 'Logistic Regression', 'accuracy': 0.8689, 'f1_score': 0.8667, 'roc_auc': 0.9535}
